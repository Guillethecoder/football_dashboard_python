# %%
import pandas as pd
import numpy as np
import os
import math

# %%
#GET COMPETITONS
df = pd.read_json('data/competitions.json')
df = df[df["season_name"].isin(["2018/2019", "2019/2020"])]
df = df[df["competition_gender"] == "male"]

#JOIN MATCHES
matches_list = []

for j in df["competition_id"].unique():
    comp = df[df["competition_id"] == j]
    for i in comp["season_id"]:
        season = pd.read_json('data/matches/{}/{}.json'.format(j,i))
        matches_list.append(season)

matches = pd.concat(matches_list)
#print(matches[["competition_name", "season_name"]])

#JOIN EVENTS
event_list = []
for i in matches['match_id']:
    event = pd.read_json('data/events/{}.json'.format(str(i)))
    event["match_id"] = i
    event = event[["minute", "type",
           "team", "player", "location",
           "shot", "match_id"]]
    event_list.append(event)

df = pd.concat(event_list)
df = pd.merge(df, matches, on="match_id")

# %%
def calculate_shot_angle(x, y):
    #x = df['X']
    #y = df['Y']
    if x > 60:
        xp1, yp1, xp2, yp2 = 120, 36, 120, 44
    else:
        xp1, yp1, xp2, yp2 = 0, 36, 0, 44
    vec1 = (xp1 - x, yp1 - y)
    vec2 = (xp2 - x, yp2 - y)
    
    angle = np.arccos((vec1[0]*vec2[0] + vec1[1]*vec2[1])/(math.sqrt((vec1[0]**2 + vec1[1]**2)*(vec2[0]**2 + vec2[1]**2))))
    return angle

def calculate_shot_distance(x, y):
    if x > 60:
        px,py = 120, 40
    else:
        px,py = 0, 40
    
    
    distance = math.sqrt((px - x)**2 + (py - y)**2)
    return distance

# %%
df = pd.concat([df, df["type"].apply(pd.Series).add_prefix('type_')], axis=1)
df = df.drop(columns = "type")
df = df[df["type_id"] == 16]
df = df.drop(columns = ["type_id", "type_name"])

# %%
df
# Out:
#         minute                                     team  \
# 33           1          {'id': 24, 'name': 'Liverpool'}
# 341          9  {'id': 38, 'name': 'Tottenham Hotspur'}
# 586         16          {'id': 24, 'name': 'Liverpool'}
# 757         20          {'id': 24, 'name': 'Liverpool'}
# 767         21          {'id': 24, 'name': 'Liverpool'}
# ...        ...                                      ...
# 266939      78        {'id': 209, 'name': 'Celta Vigo'}
# 267003      80        {'id': 209, 'name': 'Celta Vigo'}
# 267115      82        {'id': 209, 'name': 'Celta Vigo'}
# 267498      89         {'id': 217, 'name': 'Barcelona'}
# 267549      91         {'id': 217, 'name': 'Barcelona'}
#
#                                                    player       location  \
# 33                  {'id': 3531, 'name': 'Mohamed Salah'}  [108.2, 40.1]
# 341                {'id': 3091, 'name': 'Moussa Sissoko'}   [91.9, 43.1]
# 586        {'id': 3664, 'name': 'Trent Alexander-Arnold'}   [90.2, 59.3]
# 757                 {'id': 3531, 'name': 'Mohamed Salah'}   [95.2, 47.2]
# 767                 {'id': 3531, 'name': 'Mohamed Salah'}  [113.0, 59.5]
# ...                                                   ...            ...
# 266939  {'id': 11389, 'name': 'Francisco José Beltrán ...  [107.4, 26.1]
# 267003  {'id': 11389, 'name': 'Francisco José Beltrán ...  [102.7, 46.1]
# 267115       {'id': 6799, 'name': 'Brais Méndez Portela'}  [100.9, 62.1]
# 267498  {'id': 3501, 'name': 'Philippe Coutinho Correia'}   [93.9, 28.7]
# 267549  {'id': 5503, 'name': 'Lionel Andrés Messi Cucc...   [99.4, 26.7]
#
#                                                      shot  match_id  \
# 33      {'statsbomb_xg': 0.76, 'end_location': [120.0,...     22912
# 341     {'statsbomb_xg': 0.01876838, 'end_location': [...     22912
# 586     {'statsbomb_xg': 0.011493988, 'end_location': ...     22912
# 757     {'statsbomb_xg': 0.037931150000000004, 'end_lo...     22912
# 767     {'statsbomb_xg': 0.00983486, 'end_location': [...     22912
# ...                                                   ...       ...
# 266939  {'statsbomb_xg': 0.050016288000000006, 'end_lo...     16109
# 267003  {'statsbomb_xg': 0.03473995, 'end_location': [...     16109
# 267115  {'statsbomb_xg': 0.010457277000000001, 'end_lo...     16109
# 267498  {'statsbomb_xg': 0.022750404000000002, 'end_lo...     16109
# 267549  {'statsbomb_xg': 0.08562533600000001, 'end_loc...     16109
#
#         match_date      kick_off  \
# 33      2019-06-01  21:00:00.000
# 341     2019-06-01  21:00:00.000
# 586     2019-06-01  21:00:00.000
# 757     2019-06-01  21:00:00.000
# 767     2019-06-01  21:00:00.000
# ...            ...           ...
# 266939  2018-12-22  18:30:00.000
# 267003  2018-12-22  18:30:00.000
# 267115  2018-12-22  18:30:00.000
# 267498  2018-12-22  18:30:00.000
# 267549  2018-12-22  18:30:00.000
#
#                                               competition  \
# 33      {'competition_id': 16, 'country_name': 'Europe...
# 341     {'competition_id': 16, 'country_name': 'Europe...
# 586     {'competition_id': 16, 'country_name': 'Europe...
# 757     {'competition_id': 16, 'country_name': 'Europe...
# 767     {'competition_id': 16, 'country_name': 'Europe...
# ...                                                   ...
# 266939  {'competition_id': 11, 'country_name': 'Spain'...
# 267003  {'competition_id': 11, 'country_name': 'Spain'...
# 267115  {'competition_id': 11, 'country_name': 'Spain'...
# 267498  {'competition_id': 11, 'country_name': 'Spain'...
# 267549  {'competition_id': 11, 'country_name': 'Spain'...
#
#                                               season  ... away_score  \
# 33      {'season_id': 4, 'season_name': '2018/2019'}  ...          2
# 341     {'season_id': 4, 'season_name': '2018/2019'}  ...          2
# 586     {'season_id': 4, 'season_name': '2018/2019'}  ...          2
# 757     {'season_id': 4, 'season_name': '2018/2019'}  ...          2
# 767     {'season_id': 4, 'season_name': '2018/2019'}  ...          2
# ...                                              ...  ...        ...
# 266939  {'season_id': 4, 'season_name': '2018/2019'}  ...          0
# 267003  {'season_id': 4, 'season_name': '2018/2019'}  ...          0
# 267115  {'season_id': 4, 'season_name': '2018/2019'}  ...          0
# 267498  {'season_id': 4, 'season_name': '2018/2019'}  ...          0
# 267549  {'season_id': 4, 'season_name': '2018/2019'}  ...          0
#
#        match_status  match_status_360                last_updated  \
# 33        available       unscheduled            2020-07-29T05:00
# 341       available       unscheduled            2020-07-29T05:00
# 586       available       unscheduled            2020-07-29T05:00
# 757       available       unscheduled            2020-07-29T05:00
# 767       available       unscheduled            2020-07-29T05:00
# ...             ...               ...                         ...
# 266939    available        processing  2021-04-11T22:02:53.549416
# 267003    available        processing  2021-04-11T22:02:53.549416
# 267115    available        processing  2021-04-11T22:02:53.549416
# 267498    available        processing  2021-04-11T22:02:53.549416
# 267549    available        processing  2021-04-11T22:02:53.549416
#
#        last_updated_360                                           metadata  \
# 33                  NaN  {'data_version': '1.1.0', 'shot_fidelity_versi...
# 341                 NaN  {'data_version': '1.1.0', 'shot_fidelity_versi...
# 586                 NaN  {'data_version': '1.1.0', 'shot_fidelity_versi...
# 757                 NaN  {'data_version': '1.1.0', 'shot_fidelity_versi...
# 767                 NaN  {'data_version': '1.1.0', 'shot_fidelity_versi...
# ...                 ...                                                ...
# 266939              NaN  {'data_version': '1.0.3', 'shot_fidelity_versi...
# 267003              NaN  {'data_version': '1.0.3', 'shot_fidelity_versi...
# 267115              NaN  {'data_version': '1.0.3', 'shot_fidelity_versi...
# 267498              NaN  {'data_version': '1.0.3', 'shot_fidelity_versi...
# 267549              NaN  {'data_version': '1.0.3', 'shot_fidelity_versi...
#
#        match_week                    competition_stage  \
# 33             13          {'id': 26, 'name': 'Final'}
# 341            13          {'id': 26, 'name': 'Final'}
# 586            13          {'id': 26, 'name': 'Final'}
# 757            13          {'id': 26, 'name': 'Final'}
# 767            13          {'id': 26, 'name': 'Final'}
# ...           ...                                  ...
# 266939         17  {'id': 1, 'name': 'Regular Season'}
# 267003         17  {'id': 1, 'name': 'Regular Season'}
# 267115         17  {'id': 1, 'name': 'Regular Season'}
# 267498         17  {'id': 1, 'name': 'Regular Season'}
# 267549         17  {'id': 1, 'name': 'Regular Season'}
#
#                                                   stadium  \
# 33                                                    NaN
# 341                                                   NaN
# 586                                                   NaN
# 757                                                   NaN
# 767                                                   NaN
# ...                                                   ...
# 266939  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 267003  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 267115  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 267498  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
# 267549  {'id': 342, 'name': 'Camp Nou', 'country': {'i...
#
#                                                   referee
# 33                                                    NaN
# 341                                                   NaN
# 586                                                   NaN
# 757                                                   NaN
# 767                                                   NaN
# ...                                                   ...
# 266939  {'id': 453, 'name': 'Eduardo Prieto Iglesias',...
# 267003  {'id': 453, 'name': 'Eduardo Prieto Iglesias',...
# 267115  {'id': 453, 'name': 'Eduardo Prieto Iglesias',...
# 267498  {'id': 453, 'name': 'Eduardo Prieto Iglesias',...
# 267549  {'id': 453, 'name': 'Eduardo Prieto Iglesias',...
#
# [1667 rows x 23 columns]

# %%
df = pd.concat([df, df["player"].apply(pd.Series).add_prefix('player_')], axis=1)
df = df.drop(columns = "player")




df = pd.concat([df, df["location"].apply(pd.Series).rename({0: 'X', 1: 'Y'}, axis=1)], axis=1)
df = df.drop(columns = "location")




df = pd.concat([df, df["team"].apply(pd.Series).add_prefix('team_')], axis=1)
df = df.drop(columns = "team")





"""df = pd.concat([df, df["shot"].apply(pd.Series)], axis=1)
df = df.drop(columns = "shot")"""
# Out:
# 'df = pd.concat([df, df["shot"].apply(pd.Series)], axis=1)\ndf = df.drop(columns = "shot")'

# %%
df = pd.concat([df, df["competition"].apply(pd.Series)], axis=1)
df = df.drop(columns = "competition")




df = pd.concat([df, df["season"].apply(pd.Series)], axis=1)
df = df.drop(columns = "season")




df = pd.concat([df, df["home_team"].apply(pd.Series)], axis=1)
df = df.drop(columns = "home_team")





df = pd.concat([df, df["away_team"].apply(pd.Series)], axis=1)
df = df.drop(columns = "away_team")

# %%
df = pd.concat([df, df["competition_stage"].apply(pd.Series).add_prefix('competition_stage_')], axis=1)
df = df.drop(columns = ["competition_stage", "competition_stage_id"])

# %%
df = pd.concat([df, df["stadium"].apply(pd.Series).add_prefix('stadium_')], axis=1)
df = df.drop(columns = ["stadium", "stadium_id", "stadium_0" , "stadium_country"])

# %%
df = df.drop(columns=['match_status', 'match_status_360', 'last_updated',
       'last_updated_360', 'metadata', 'referee', 'home_team_gender',
                     'away_team_gender', 'home_team_group', 'away_team_group',
                     'managers', 'country', 'country_name'])

# %%
df = pd.concat([df, df["shot"].apply(pd.Series)], axis=1)
df = df.drop(columns = "shot")

# %%
df=df.drop(columns = ["key_pass_id", "first_time", "aerial_won",
                            'freeze_frame', 'one_on_one','saved_to_post',
                           'redirect','open_goal','redirect', 'deflected',
                           'saved_off_target', 'follows_dribble'])

# %%
df = pd.concat([df, df["technique"].apply(pd.Series).add_prefix('technique_')], axis=1)
df = df.drop(columns = ["technique","technique_id"])


df = pd.concat([df, df["outcome"].apply(pd.Series).add_prefix('outcome_')], axis=1)
df = df.drop(columns = ["outcome","outcome_id"])


df = pd.concat([df, df["type"].apply(pd.Series).add_prefix('type_')], axis=1)
df = df.drop(columns = ["type","type_id"])


df = pd.concat([df, df["body_part"].apply(pd.Series).add_prefix('body_part_')], axis=1)
df = df.drop(columns = ["body_part","body_part_id"])

# %%
df["Goal"] = df["outcome_name"] == "Goal"

# %%
df['theta'] = None
df['theta'] = df.apply(lambda row : calculate_shot_angle(row['X'],
                     row['Y']), axis = 1)
df = df.dropna(subset=['theta']) 
df['distance'] = None
df['distance'] = df.apply(lambda row : calculate_shot_distance(row['X'],
                     row['Y']), axis = 1)

# %%
df.to_csv("all_shots_18_20.csv")
